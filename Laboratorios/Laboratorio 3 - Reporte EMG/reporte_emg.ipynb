# %% [markdown]
# # 📚 INTRODUCCIÓN
#
# La electromiografía (EMG) es una técnica utilizada para registrar la actividad eléctrica generada por los músculos esqueléticos durante el reposo y la contracción. El análisis de señales EMG permite estudiar el funcionamiento neuromuscular, identificar patrones de activación muscular y evaluar la respuesta ante diferentes tipos de movimientos y esfuerzos. En este laboratorio, se registraron señales EMG de distintos músculos (bíceps, músculos faciales y abductor corto del pulgar) bajo condiciones de reposo, movimientos voluntarios y contrafuerza, con el objetivo de comparar la actividad eléctrica en cada situación y comprender la fisiología subyacente.

# %% [markdown]
# # 🔎 OBJETIVOS
#
# - Registrar y analizar señales EMG de diferentes grupos musculares en condiciones de reposo, movimiento voluntario y contrafuerza.
# - Comparar la actividad eléctrica muscular entre las distintas condiciones y movimientos.
# - Visualizar y describir las diferencias en la señal EMG según el tipo de músculo y el esfuerzo realizado.
# - Comprender la relación entre la señal EMG y la activación muscular durante distintas tareas motoras.

# %% [markdown]
# # 👨🏻‍💻 MATERIALES
#
# - **LAPTOP** – La laptop se utiliza para correr el software [**OpenSignals**](https://support.pluxbiosignals.com/knowledge-base/introducing-opensignals-revolution/), que permite visualizar, registrar y analizar en tiempo real las señales adquiridas por el BITalino.
#   <p align="center">
#     <img src="https://i.dell.com/is/image/DellContent/content/dam/ss2/product-images/dell-client-products/notebooks/dell-plus/db14255/media-gallery/touch/fpr/laptop-db14255t-bl-fpr-gallery-2.psd?fmt=png-alpha&pscan=auto&scl=1&hei=804&wid=975&qlt=100,1&resMode=sharp2&size=975,804&chrss=full" width="250"/>
#   </p>
#   <p align="center">
#     Figura 01 - Imagen referencial de laptop con OpenSignals
#   </p>
#
#
# - **Un microcontrolador BITalino para adquisición de bioseñales** – El **BITalino** es una placa biomédica de bajo costo diseñada para adquirir señales fisiológicas como ECG, EMG, EDA o acelerómetro. Se usa en investigación, docencia y prototipado.
#   <p align="center">
#     <img src="https://prototipadolab.com/wp-content/uploads/2018/08/bitalino.jpg" width="250"/>
#   </p>
#   <p align="center">
#   Figura 02 - BITalino
#   </p>
#
# - **3 Electrodos desechables** – Son adhesivos con gel conductor que se colocan sobre la piel para captar la actividad eléctrica. Son de un solo uso para asegurar buena calidad de señal e higiene.
#   <p align="center">
#     <img src="https://mecatronica.saisac.pe/wp-content/uploads/2024/10/ELECTRODO.png" width="250"/>
#   </p>
#   <p align="center">
#   Figura 03 - Electrodos desechables
#   </p>
#
# - **3 cables de electrodos (Lead I, sistema de 3 electrodos)** – El **Lead I** en configuración de 3 electrodos se coloca en brazo derecho, brazo izquierdo y pierna derecha (tierra). Permite medir la diferencia de potencial entre ambos brazos para el registro de ECG.
#   <p align="center">
#     <img src="https://mecatronica.saisac.pe/wp-content/uploads/2024/10/CABLEELECTRODO.png" width="250"/>
#   </p>
#   <p align="center">
#   Figura 04 - Lead I Sistema de 3 electrodos
#   </p>

# %% [markdown]
# # ✨RESULTADOS

# %% [markdown]
# # **1. Toma de datos - Músculo 01 - BÍCEPS 💪🏻⚡**
#
# ## 1.1. Ubicación de electrodos
#
# ### ✅ Materiales
# - 2 electrodos desechables (activos)
# - 1 electrodo de referencia/masa (tierra)
# - Toallitas con alcohol o algodón con alcohol
# - Tijera pequeña si hay mucho vello
# - BITalino y laptop con **OpenSignals**
#
# ### 🛡️ Antes de empezar
# - El EMG **solo registra** la electricidad del músculo, no introduce corriente.
# - No usar electrodos sobre heridas o piel irritada.
# - Los electrodos son **desechables** para higiene y buena calidad de señal.
#
# ### 🔎 Paso a paso
#
# 1. **Coloca a la persona**
#    - Sentada, con la espalda recta.
#    - El brazo relajado o con el codo a 90°, palma hacia arriba.
#
# 2. **Localiza la línea guía**
#    - Imagina una línea desde el **hombro (acromion)** hasta el **pliegue del codo (fosa cubital)**.
#
# 3. **Marca la posición central**
#    - Encuentra el punto que está a **1/3 de la distancia desde el codo hacia el hombro**.
#    - Ese es el centro del par de electrodos.
#
# 4. **Prepara la piel**
#    - Recorta el vello si es necesario.
#    - Limpia con alcohol y deja secar.
#
# 5. **Coloca los 2 electrodos activos**
#    - Pégalos en el vientre del bíceps, **alineados con las fibras musculares**.
#    - Mantén una separación de **≈20 mm (2 cm)** entre los centros.
#
# 6. **Coloca el electrodo de referencia (tierra)**
#    - Ponlo en una zona ósea o sin músculo cercano, para este experimento se usó la muñeca.
#
# 7. **Prueba la señal**
#    - Pide que la persona flexione el codo.
#    - En **OpenSignals** verás cómo la señal aumenta cuando el bíceps se activa.
#
# 8. **Evita errores comunes**
#    - No pegar los electrodos sobre tendones.
#    - No separar demasiado los electrodos (para no captar otros músculos).
#
#
# <p align="center">
#    <img src="https://electrotens.com/wp-content/uploads/2023/10/COLOCACION-DE-LOS-ELECTRODOS-SOBRE-BICEPS.jpg" width="400"/>
# </p>
# <p align="center">
#    Figura 05 - Imagen referencial de ubicación de electrodos
# </p>

# %% [markdown]
# ## 1.2. Bíceps en reposo
# 👉🏻 Acceso directo para visualizar [Bíceps en reposo](https://drive.google.com/file/d/1fKtBrso6JJ8-2UGbb3jayQTGAZRgNSKI/view?usp=drive_link)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Cargar archivo
signal = np.loadtxt("Data_EMG/biceps reposo.txt")
# Seleccionar la columna 5 (para poder eliminar valores pequeños o ceros)
reposo = np.loadtxt("Data_EMG/biceps reposo.txt", comments="#")[:,5]

fs = 1000  # frecuencia de muestreo
t = np.arange(len(signal)) / fs

# Mostrar 10 segundos (10000 muestras)
samples = 10000
# Graficar
plt.figure(figsize=(12,5))
plt.plot(t[:samples], reposo[:samples], color="blue")

plt.title("Señal EMG - Bíceps en reposo", fontsize=14, fontweight="bold")
plt.xlabel("Tiempo [s]", fontsize=12)
plt.ylabel("Amplitud [µV]", fontsize=12)

# Acotar el eje Y 
plt.ylim(400, 700)
plt.grid(True, linestyle="--", alpha=0.6)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 1.3 Bíceps - Movimientos voluntarios
# ### 1.3.1. Toma 1
# 👉🏻 Acceso directo para la visualización de [Bíceps Movimiento Voluntario Toma 1](https://drive.google.com/file/d/1H1PM4vBGgDvlrex9F_H97XYTQvga2a99/view?usp=drive_link)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Cargar datos
reposo = np.loadtxt("Data_EMG/biceps reposo.txt", comments="#")[:,5]
voluntario = np.loadtxt("Data_EMG/biceps voluntario 1.txt", comments="#")[:,5]

fs = 1000
t = np.arange(len(reposo)) / fs

# Mostrar 10 segundos (10000 muestras)
samples = 10000

plt.figure(figsize=(12,6))

plt.subplot(2,1,1)
plt.plot(t[:samples], reposo[:samples], color="blue")
plt.title("Señal EMG - Bíceps en reposo", fontsize=14, fontweight="bold")
plt.xlabel("Tiempo [s]"); plt.ylabel("Amplitud [µV]")
plt.ylim(400,700); plt.grid(True, linestyle="--", alpha=0.6)

plt.subplot(2,1,2)
plt.plot(t[:samples], voluntario[:samples], color="red")
plt.title("Señal EMG - Bíceps en movimiento voluntario N°1", fontsize=14, fontweight="bold")
plt.xlabel("Tiempo [s]"); plt.ylabel("Amplitud [µV]")
plt.ylim(400,700); plt.grid(True, linestyle="--", alpha=0.6)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 1.3.2. Toma 2
# 👉🏻 Acceso directo para la visualización de [Bíceps Movimiento Voluntario Toma 2](https://drive.google.com/file/d/1XP7bIy8dEa4Af7TYc5YKUdxIw4BPzMPw/view?usp=drive_link)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Cargar datos
reposo = np.loadtxt("Data_EMG/biceps reposo.txt", comments="#")[:,5]
voluntario = np.loadtxt("Data_EMG/biceps voluntario 2.txt", comments="#")[:,5]

fs = 1000
t = np.arange(len(reposo)) / fs

# Mostrar 10 segundos (10000 muestras)
samples = 10000

plt.figure(figsize=(12,6))

plt.subplot(2,1,1)
plt.plot(t[:samples], reposo[:samples], color="blue")
plt.title("Señal EMG - Bíceps en reposo", fontsize=14, fontweight="bold")
plt.xlabel("Tiempo [s]"); plt.ylabel("Amplitud [µV]")
plt.ylim(400,700); plt.grid(True, linestyle="--", alpha=0.6)

plt.subplot(2,1,2)
plt.plot(t[:samples], voluntario[:samples], color="red")
plt.title("Señal EMG - Bíceps en movimiento voluntario N°2", fontsize=14, fontweight="bold")
plt.xlabel("Tiempo [s]"); plt.ylabel("Amplitud [µV]")
plt.ylim(400,700); plt.grid(True, linestyle="--", alpha=0.6)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 1.3.3. Toma 3
# 👉🏻 Acceso directo para la visualización de [Bíceps Movimiento Voluntario Toma 3](https://drive.google.com/file/d/1koC5y6WL_OKVmQqM2gKn87nPpYJP1oy0/view?usp=drive_link)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Cargar datos
reposo = np.loadtxt("Data_EMG/biceps reposo.txt", comments="#")[:,5]
voluntario = np.loadtxt("Data_EMG/biceps voluntario 3.txt", comments="#")[:,5]

fs = 1000
t = np.arange(len(reposo)) / fs

# Mostrar 10 segundos (10000 muestras)
samples = 10000

plt.figure(figsize=(12,6))

plt.subplot(2,1,1)
plt.plot(t[:samples], reposo[:samples], color="blue")
plt.title("Señal EMG - Bíceps en reposo", fontsize=14, fontweight="bold")
plt.xlabel("Tiempo [s]"); plt.ylabel("Amplitud [µV]")
plt.ylim(400,700); plt.grid(True, linestyle="--", alpha=0.6)

plt.subplot(2,1,2)
plt.plot(t[:samples], voluntario[:samples], color="red")
plt.title("Señal EMG - Bíceps en movimiento voluntario N°3", fontsize=14, fontweight="bold")
plt.xlabel("Tiempo [s]"); plt.ylabel("Amplitud [µV]")
plt.ylim(400,700); plt.grid(True, linestyle="--", alpha=0.6)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 1.4 Bíceps - Movimientos con contrafuerza
# ### 1.4.1. Toma 1
# 👉🏻 Acceso directo para la visualización de [Bíceps Movimiento con Contrafuerza Toma 1](https://drive.google.com/file/d/1DlHPUgWC78L7Op694JN_-NE1WYsNaf1e/view?usp=drive_link)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Cargar datos
reposo = np.loadtxt("Data_EMG/biceps reposo.txt", comments="#")[:,5]
voluntario = np.loadtxt("Data_EMG/biceps contrafuerza 1.txt", comments="#")[:,5]

fs = 1000
t = np.arange(len(reposo)) / fs

# Mostrar 10 segundos (10000 muestras)
samples = 10000

plt.figure(figsize=(12,6))

plt.subplot(2,1,1)
plt.plot(t[:samples], reposo[:samples], color="blue")
plt.title("Señal EMG - Bíceps en reposo", fontsize=14, fontweight="bold")
plt.xlabel("Tiempo [s]"); plt.ylabel("Amplitud [µV]")
plt.ylim(400,700); plt.grid(True, linestyle="--", alpha=0.6)

plt.subplot(2,1,2)
plt.plot(t[:samples], voluntario[:samples], color="red")
plt.title("Señal EMG - Bíceps en movimiento contrafuerza  N°1", fontsize=14, fontweight="bold")
plt.xlabel("Tiempo [s]"); plt.ylabel("Amplitud [µV]")
plt.ylim(400,700); plt.grid(True, linestyle="--", alpha=0.6)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 1.4.2. Toma 2
# 👉🏻 Acceso directo para la visualización de [Bíceps Movimiento con Contrafuerza Toma 2](https://drive.google.com/file/d/19cHvgZuZy7vZvG39Zw8zsBtESDbf01Pz/view?usp=drive_link)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Cargar datos
reposo = np.loadtxt("Data_EMG/biceps reposo.txt", comments="#")[:,5]
voluntario = np.loadtxt("Data_EMG/biceps contrafuerza 2.txt", comments="#")[:,5]

fs = 1000
t = np.arange(len(reposo)) / fs

# Mostrar 10 segundos (10000 muestras)
samples = 10000

plt.figure(figsize=(12,6))

plt.subplot(2,1,1)
plt.plot(t[:samples], reposo[:samples], color="blue")
plt.title("Señal EMG - Bíceps en reposo", fontsize=14, fontweight="bold")
plt.xlabel("Tiempo [s]"); plt.ylabel("Amplitud [µV]")
plt.ylim(400,700); plt.grid(True, linestyle="--", alpha=0.6)

plt.subplot(2,1,2)
plt.plot(t[:samples], voluntario[:samples], color="red")
plt.title("Señal EMG - Bíceps en movimiento contrafuerza  N°2", fontsize=14, fontweight="bold")
plt.xlabel("Tiempo [s]"); plt.ylabel("Amplitud [µV]")
plt.ylim(400,700); plt.grid(True, linestyle="--", alpha=0.6)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 1.4.3. Toma 3
# 👉🏻 Acceso directo para la visualización de [Bíceps Movimiento con Contrafuerza Toma 3](https://drive.google.com/file/d/1KHWZB6CLDs47QgraADcOj3WNX5f1mLPL/view?usp=drive_link)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Cargar datos
reposo = np.loadtxt("Data_EMG/biceps reposo.txt", comments="#")[:,5]
voluntario = np.loadtxt("Data_EMG/biceps contrafuerza 3.txt", comments="#")[:,5]

fs = 1000
t = np.arange(len(reposo)) / fs

# Mostrar 10 segundos (10000 muestras)
samples = 10000

plt.figure(figsize=(12,6))

plt.subplot(2,1,1)
plt.plot(t[:samples], reposo[:samples], color="blue")
plt.title("Señal EMG - Bíceps en reposo", fontsize=14, fontweight="bold")
plt.xlabel("Tiempo [s]"); plt.ylabel("Amplitud [µV]")
plt.ylim(400,700); plt.grid(True, linestyle="--", alpha=0.6)

plt.subplot(2,1,2)
plt.plot(t[:samples], voluntario[:samples], color="red")
plt.title("Señal EMG - Bíceps en movimiento contrafuerza  N°3", fontsize=14, fontweight="bold")
plt.xlabel("Tiempo [s]"); plt.ylabel("Amplitud [µV]")
plt.ylim(400,700); plt.grid(True, linestyle="--", alpha=0.6)

plt.tight_layout()
plt.show()

# %% [markdown]
# # **2. Toma de datos - Músculo 02 - MÚSCULOS FACIALES** 😆😁
#
# ## 2.1. Ubicación de electrodos
#
# ### ✅ Materiales
# - 2 electrodos superficiales desechables (activos)
# - 1 electrodo de referencia/masa (tierra)
# - Toallitas con alcohol o algodón con alcohol
# - Cinta médica para fijar cables
# - BITalino y laptop con **OpenSignals**
#
# ### 🛡️ Antes de empezar
# - El EMG **no duele** y solo registra la electricidad del músculo.
# - Usa electrodos desechables por higiene.
# - Evita colocarlos sobre granitos, heridas o piel irritada.
# - Pide a la persona que esté tranquila y sin moverse mucho.
#
# ### 🔎 Paso a paso (ejemplo: músculo masetero o cigomático)
#
# 1. **Coloca a la persona**
#    - Sentada, con la cabeza relajada y mirando al frente.
#
# 2. **Elige el músculo de la cara**
#    - **Masetero:** músculo de la mandíbula, se activa al apretar los dientes.
#    - **Cigomático mayor:** músculo de la mejilla, se activa al sonreír.
#
# 3. **Prepara la piel**
#    - Limpia suavemente con una toallita con alcohol.
#    - Deja que se seque antes de colocar los electrodos.
#
# 4. **Coloca los 2 electrodos activos**
#    - Pégalos **paralelos a las fibras del músculo elegido**.
#    - Mantén una separación pequeña: **≈10–15 mm** (1 a 1.5 cm).
#    - Ejemplo:
#      - Masetero → ponlos en la parte lateral de la mandíbula, entre el pómulo y el ángulo de la quijada.
#      - Cigomático → ponlos en la mejilla, desde el pómulo hacia la comisura de la boca.
#
# 5. **Coloca el electrodo de referencia (tierra)**
#    - Ponlo en una zona neutra sin mucha actividad muscular, por ejemplo detrás de la oreja.
#
# 6. **Prueba la señal**
#    - Pide a la persona que sonría (cigomático) o que apriete los dientes (masetero).
#    - En **OpenSignals**, deberías ver cómo la señal aumenta durante la contracción.

# %% [markdown]
# ## 2.2. Músculos faciales en reposo
# 👉🏻 Acceso directo para visualizar [Músculos faciales en reposo](https://drive.google.com/file/d/1RY_HJ0GoWTbk_2NgcPEEqCi2d4Eu4ylV/view?usp=drive_link)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Cargar archivo
signal = np.loadtxt("Data_EMG/cara reposo 1.txt")
# Seleccionar la columna 5 (para poder eliminar valores pequeños o ceros)
reposo = np.loadtxt("Data_EMG/cara reposo 1.txt", comments="#")[:,5]

fs = 1000  # frecuencia de muestreo
t = np.arange(len(signal)) / fs

# Mostrar 10 segundos (10000 muestras)
samples = 10000
# Graficar
plt.figure(figsize=(12,5))
plt.plot(t[:samples], reposo[:samples], color="blue")

plt.title("Señal EMG - Cara en reposo", fontsize=14, fontweight="bold")
plt.xlabel("Tiempo [s]", fontsize=12)
plt.ylabel("Amplitud [µV]", fontsize=12)

# Acotar el eje Y 
plt.ylim(400, 700)
plt.grid(True, linestyle="--", alpha=0.6)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 2.3. Músculos faciales - Movimientos Voluntarios
# ### 2.3.1. Toma 1
# 👉🏻 Acceso directo para visualizar [Músculos faciales Movimientos Voluntarios Toma 1] (https://drive.google.com/file/d/19L3UMDkEU74QlldRLi03R6O2Q4g_O41n/view?usp=drive_link)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Cargar datos
reposo = np.loadtxt("Data_EMG/cara reposo 1.txt", comments="#")[:,5]
voluntario = np.loadtxt("Data_EMG/cara mov 1.txt", comments="#")[:,5]

fs = 1000
t = np.arange(len(reposo)) / fs

# Mostrar 10 segundos (10000 muestras)
samples = 10000

plt.figure(figsize=(12,6))

plt.subplot(2,1,1)
plt.plot(t[:samples], reposo[:samples], color="blue")
plt.title("Señal EMG - Cara en reposo", fontsize=14, fontweight="bold")
plt.xlabel("Tiempo [s]"); plt.ylabel("Amplitud [µV]")
plt.ylim(400,700); plt.grid(True, linestyle="--", alpha=0.6)

plt.subplot(2,1,2)
plt.plot(t[:samples], voluntario[:samples], color="red")
plt.title("Señal EMG - Cara en movimiento N°1", fontsize=14, fontweight="bold")
plt.xlabel("Tiempo [s]"); plt.ylabel("Amplitud [µV]")
plt.ylim(400,700); plt.grid(True, linestyle="--", alpha=0.6)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 2.3.2. Toma 2
# 👉🏻 Acceso directo para visualizar [Músculos faciales Movimientos Voluntarios Toma 2](https://drive.google.com/file/d/1-7eNA9Xs8BggZTjd8Vt8aLiCuM3di318/view?usp=drive_link)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Cargar datos
reposo = np.loadtxt("Data_EMG/cara reposo 1.txt", comments="#")[:,5]
voluntario = np.loadtxt("Data_EMG/cara mov 2.txt", comments="#")[:,5]

fs = 1000
t = np.arange(len(reposo)) / fs

# Mostrar 10 segundos (10000 muestras)
samples = 10000

plt.figure(figsize=(12,6))

plt.subplot(2,1,1)
plt.plot(t[:samples], reposo[:samples], color="blue")
plt.title("Señal EMG - Cara en reposo", fontsize=14, fontweight="bold")
plt.xlabel("Tiempo [s]"); plt.ylabel("Amplitud [µV]")
plt.ylim(400,700); plt.grid(True, linestyle="--", alpha=0.6)

plt.subplot(2,1,2)
plt.plot(t[:samples], voluntario[:samples], color="red")
plt.title("Señal EMG - Cara en movimiento N°2", fontsize=14, fontweight="bold")
plt.xlabel("Tiempo [s]"); plt.ylabel("Amplitud [µV]")
plt.ylim(400,700); plt.grid(True, linestyle="--", alpha=0.6)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 2.3.3. Toma 3
# 👉🏻 Acceso directo para visualizar [Músculos faciales Movimientos Voluntarios Toma 3](https://drive.google.com/file/d/14oUawCFzao1T2MUhooXmO4ZmbdZncBUt/view?usp=drive_link)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Cargar datos
reposo = np.loadtxt("Data_EMG/cara reposo 1.txt", comments="#")[:,5]
voluntario = np.loadtxt("Data_EMG/cara mov 3.txt", comments="#")[:,5]

fs = 1000
t = np.arange(len(reposo)) / fs

# Mostrar 10 segundos (10000 muestras)
samples = 10000

plt.figure(figsize=(12,6))

plt.subplot(2,1,1)
plt.plot(t[:samples], reposo[:samples], color="blue")
plt.title("Señal EMG - Cara en reposo", fontsize=14, fontweight="bold")
plt.xlabel("Tiempo [s]"); plt.ylabel("Amplitud [µV]")
plt.ylim(400,700); plt.grid(True, linestyle="--", alpha=0.6)

plt.subplot(2,1,2)
plt.plot(t[:samples], voluntario[:samples], color="red")
plt.title("Señal EMG - Cara en movimiento N°3", fontsize=14, fontweight="bold")
plt.xlabel("Tiempo [s]"); plt.ylabel("Amplitud [µV]")
plt.ylim(400,700); plt.grid(True, linestyle="--", alpha=0.6)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Movimiento -  Abductor corto del pulgar (pulgar)
# ## Abductor corto del pulgar en reposo

# %%
import numpy as np
import matplotlib.pyplot as plt

# Cargar archivo
signal = np.loadtxt("Data_EMG/muñeca reposo 1.txt")
# Seleccionar la columna 5 (para poder eliminar valores pequeños o ceros)
reposo = np.loadtxt("Data_EMG/muñeca reposo 1.txt", comments="#")[:,5]

fs = 1000  # frecuencia de muestreo
t = np.arange(len(signal)) / fs

# Mostrar 10 segundos (10000 muestras)
samples = 10000
# Graficar
plt.figure(figsize=(12,5))
plt.plot(t[:samples], reposo[:samples], color="blue")

plt.title("Señal EMG - Abductor corto del pulgar en reposo", fontsize=14, fontweight="bold")
plt.xlabel("Tiempo [s]", fontsize=12)
plt.ylabel("Amplitud [µV]", fontsize=12)

# Acotar el eje Y 
plt.ylim(-100, 1100)
plt.grid(True, linestyle="--", alpha=0.6)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Abductor corto del pulgar - movimiento voluntario N°1

# %%
import numpy as np
import matplotlib.pyplot as plt

# Cargar datos
reposo = np.loadtxt("Data_EMG/muñeca reposo 1.txt", comments="#")[:,5]
voluntario = np.loadtxt("Data_EMG/muñeca mov 1.txt", comments="#")[:,5]

fs = 1000
t = np.arange(len(reposo)) / fs

# Mostrar 10 segundos (10000 muestras)
samples = 10000

plt.figure(figsize=(12,6))

plt.subplot(2,1,1)
plt.plot(t[:samples], reposo[:samples], color="blue")
plt.title("Señal EMG - Abductor corto del pulgar en reposo", fontsize=14, fontweight="bold")
plt.xlabel("Tiempo [s]"); plt.ylabel("Amplitud [µV]")
plt.ylim(-100, 1100); plt.grid(True, linestyle="--", alpha=0.6)

plt.subplot(2,1,2)
plt.plot(t[:samples], voluntario[:samples], color="red")
plt.title("Señal EMG - Abductor corto del pulgar en movimiento N°1", fontsize=14, fontweight="bold")
plt.xlabel("Tiempo [s]"); plt.ylabel("Amplitud [µV]")
plt.ylim(-100, 1100); plt.grid(True, linestyle="--", alpha=0.6)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Abductor corto del pulgar - movimiento voluntario N°2

# %%
import numpy as np
import matplotlib.pyplot as plt

# Cargar datos
reposo = np.loadtxt("Data_EMG/muñeca reposo 1.txt", comments="#")[:,5]
voluntario = np.loadtxt("Data_EMG/muñeca mov 2.txt", comments="#")[:,5]

fs = 1000
t = np.arange(len(reposo)) / fs

# Mostrar 10 segundos (10000 muestras)
samples = 10000

plt.figure(figsize=(12,6))

plt.subplot(2,1,1)
plt.plot(t[:samples], reposo[:samples], color="blue")
plt.title("Señal EMG - Abductor corto del pulgar en reposo", fontsize=14, fontweight="bold")
plt.xlabel("Tiempo [s]"); plt.ylabel("Amplitud [µV]")
plt.ylim(-100, 1100); plt.grid(True, linestyle="--", alpha=0.6)

plt.subplot(2,1,2)
plt.plot(t[:samples], voluntario[:samples], color="red")
plt.title("Señal EMG - Abductor corto del pulgar en movimiento N°2", fontsize=14, fontweight="bold")
plt.xlabel("Tiempo [s]"); plt.ylabel("Amplitud [µV]")
plt.ylim(-100, 1100); plt.grid(True, linestyle="--", alpha=0.6)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Abductor corto del pulgar - movimiento voluntario N°3

# %%
import numpy as np
import matplotlib.pyplot as plt

# Cargar datos
reposo = np.loadtxt("Data_EMG/muñeca reposo 1.txt", comments="#")[:,5]
voluntario = np.loadtxt("Data_EMG/muñeca mov 3.txt", comments="#")[:,5]

fs = 1000
t = np.arange(len(reposo)) / fs

# Mostrar 10 segundos (10000 muestras)
samples = 10000

plt.figure(figsize=(12,6))

plt.subplot(2,1,1)
plt.plot(t[:samples], reposo[:samples], color="blue")
plt.title("Señal EMG - Abductor corto del pulgar en reposo", fontsize=14, fontweight="bold")
plt.xlabel("Tiempo [s]"); plt.ylabel("Amplitud [µV]")
plt.ylim(-100, 1100); plt.grid(True, linestyle="--", alpha=0.6)

plt.subplot(2,1,2)
plt.plot(t[:samples], voluntario[:samples], color="red")
plt.title("Señal EMG - Abductor corto del pulgar en movimiento N°3", fontsize=14, fontweight="bold")
plt.xlabel("Tiempo [s]"); plt.ylabel("Amplitud [µV]")
plt.ylim(-100, 1100); plt.grid(True, linestyle="--", alpha=0.6)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Abductor corto del pulgar - movimiento contrafuerza N°1

# %%
import numpy as np
import matplotlib.pyplot as plt

# Cargar datos
reposo = np.loadtxt("Data_EMG/muñeca reposo 1.txt", comments="#")[:,5]
voluntario = np.loadtxt("Data_EMG/muñeca apretar 1.txt", comments="#")[:,5]

fs = 1000
t = np.arange(len(reposo)) / fs

# Mostrar 10 segundos (10000 muestras)
samples = 10000

plt.figure(figsize=(12,6))

plt.subplot(2,1,1)
plt.plot(t[:samples], reposo[:samples], color="blue")
plt.title("Señal EMG - Abductor corto del pulgar en reposo", fontsize=14, fontweight="bold")
plt.xlabel("Tiempo [s]"); plt.ylabel("Amplitud [µV]")
plt.ylim(-100, 1100); plt.grid(True, linestyle="--", alpha=0.6)

plt.subplot(2,1,2)
plt.plot(t[:samples], voluntario[:samples], color="red")
plt.title("Señal EMG - Abductor corto del pulgar en movimiento contrafuerza N°1", fontsize=14, fontweight="bold")
plt.xlabel("Tiempo [s]"); plt.ylabel("Amplitud [µV]")
plt.ylim(-100, 1100); plt.grid(True, linestyle="--", alpha=0.6)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Abductor corto del pulgar - movimiento contrafuerza N°2

# %%
import numpy as np
import matplotlib.pyplot as plt

# Cargar datos
reposo = np.loadtxt("Data_EMG/muñeca reposo 1.txt", comments="#")[:,5]
voluntario = np.loadtxt("Data_EMG/muñeca apretar 2.txt", comments="#")[:,5]

fs = 1000
t = np.arange(len(reposo)) / fs

# Mostrar 10 segundos (10000 muestras)
samples = 10000

plt.figure(figsize=(12,6))

plt.subplot(2,1,1)
plt.plot(t[:samples], reposo[:samples], color="blue")
plt.title("Señal EMG - Abductor corto del pulgar en reposo", fontsize=14, fontweight="bold")
plt.xlabel("Tiempo [s]"); plt.ylabel("Amplitud [µV]")
plt.ylim(-100, 1100); plt.grid(True, linestyle="--", alpha=0.6)

plt.subplot(2,1,2)
plt.plot(t[:samples], voluntario[:samples], color="red")
plt.title("Señal EMG - Abductor corto del pulgar en movimiento contrafuerza N°2", fontsize=14, fontweight="bold")
plt.xlabel("Tiempo [s]"); plt.ylabel("Amplitud [µV]")
plt.ylim(-100, 1100); plt.grid(True, linestyle="--", alpha=0.6)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Abductor corto del pulgar - movimiento contrafuerza N°3

# %%
import numpy as np
import matplotlib.pyplot as plt

# Cargar datos
reposo = np.loadtxt("Data_EMG/muñeca reposo 1.txt", comments="#")[:,5]
voluntario = np.loadtxt("Data_EMG/muñeca apretar 3.txt", comments="#")[:,5]

fs = 1000
t = np.arange(len(reposo)) / fs

# Mostrar 10 segundos (10000 muestras)
samples = 10000

plt.figure(figsize=(12,6))

plt.subplot(2,1,1)
plt.plot(t[:samples], reposo[:samples], color="blue")
plt.title("Señal EMG - Abductor corto del pulgar en reposo", fontsize=14, fontweight="bold")
plt.xlabel("Tiempo [s]"); plt.ylabel("Amplitud [µV]")
plt.ylim(-100, 1100); plt.grid(True, linestyle="--", alpha=0.6)

plt.subplot(2,1,2)
plt.plot(t[:samples], voluntario[:samples], color="red")
plt.title("Señal EMG - Abductor corto del pulgar en movimiento contrafuerza N°3", fontsize=14, fontweight="bold")
plt.xlabel("Tiempo [s]"); plt.ylabel("Amplitud [µV]")
plt.ylim(-100, 1100); plt.grid(True, linestyle="--", alpha=0.6)

plt.tight_layout()
plt.show()

# %% [markdown]
# # CONCLUSION GENERAL
#
# Podemos concluir que:
#
# - La electromiografía (EMG) permitió registrar y analizar la actividad eléctrica de diferentes grupos musculares bajo condiciones de reposo, movimiento voluntario y contrafuerza, evidenciando variaciones claras en la amplitud y el patrón de las señales según el tipo y la intensidad del movimiento.
#
# - Se observó que los músculos presentan una señal EMG de baja amplitud en reposo, mientras que durante los movimientos voluntarios y especialmente bajo contrafuerza, la amplitud y la complejidad de la señal aumentan significativamente, reflejando una mayor activación muscular.
#
# - La comparación entre los distintos músculos (bíceps, músculos faciales y abductor corto del pulgar) mostró que cada grupo muscular tiene características propias en su señal EMG, dependiendo de su función y del tipo de movimiento realizado.
#
# - El análisis de las señales EMG es fundamental para comprender la fisiología muscular y puede ser aplicado en áreas como la rehabilitación, el control de prótesis y el desarrollo de interfaces hombre-máquina.
#
# - Para el proyecto final del curso, se empleará la toma de muestras EMG del abductor corto del pulgar, ya que este músculo permite registrar movimientos precisos y es relevante para aplicaciones de control y reconocimiento de gestos en dispositivos biomédicos.
