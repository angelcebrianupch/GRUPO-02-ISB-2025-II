# %% [markdown]
# # 📚 INTRODUCCIÓN
#
# El electrocardiograma (ECG) es una de las herramientas más utilizadas en el ámbito clínico para el diagnóstico y monitoreo de enfermedades cardíacas. Su carácter no invasivo y su capacidad para registrar la actividad eléctrica del corazón lo convierten en un recurso fundamental en la práctica médica, especialmente para la detección temprana de alteraciones como arritmias, cardiomiopatías o enfermedades coronarias [1]. No obstante, gran parte de los equipos convencionales de registro y análisis de ECG suelen ser costosos y de difícil acceso en entornos educativos o de investigación aplicada.
#
# En este laboratorio se empleó la plataforma **BITalino (r)evolution**, un dispositivo portátil y de bajo costo diseñado para la adquisición de señales biomédicas, con el fin de registrar y analizar la actividad eléctrica del corazón. A través del software **OpenSignals (r)evolution**, fue posible configurar el sistema, adquirir las señales en tiempo real y representarlas gráficamente para identificar los principales componentes de un ECG: la onda **P**, el complejo **QRS** y la onda **T**, que reflejan la despolarización y repolarización de las cavidades cardíacas.
#
# <img src="https://4.bp.blogspot.com/-OinADYfGYpI/WHcR3g8P6sI/AAAAAAAAAJY/T6DJqaO9-GA_z9RsYCG737ROAIW9O_TCgCLcB/s1600/EKG_Complex_es.svg.png" alt="Ondas_ECG" width="500"/>
#
# ***Figura 01 - Ondas del electrocardiograma***
#
# De esta manera, el presente trabajo busca acercarnos al uso práctico de tecnologías biomédicas accesibles para la adquisición de señales fisiológicas. Al mismo tiempo, nos permite comprender mejor la importancia clínica del ECG como una herramienta esencial para el estudio de la función cardíaca y su potencial aplicación en el desarrollo de soluciones innovadoras dentro del campo de la ingeniería biomédica.

# %% [markdown]
# ## ⚡️ Tipos de Ondas del Electrocardiograma (ECG) [2]
#
# Ya vimos que básicamente el **electrocardiograma (ECG)** es un registro de la **electricidad del corazón**, donde en el papel o en la pantalla, se ve como una serie de **ondas** que suben y bajan. Cada onda tiene un nombre y nos cuenta algo distinto del corazón.
#
# ### 📈 Ondas principales
#
# <details>
# <summary>🟢 Onda P</summary>
#
# - Es la **primera onda** del ciclo.
# - Representa cuando las **aurículas** (las cavidades superiores del corazón) se activan.
# - Dura muy poquito, menos de **0.10 segundos**.
# - Si hay problemas en las aurículas, esta onda puede cambiar de forma.
#
# </details>
#
# <details>
# <summary>🔵 Complejo QRS</summary>
#
# - Es un grupo de ondas (Q, R y S).
# - Representa cuando los **ventrículos** (las cavidades grandes del corazón) se activan.
# - Dura entre **0.06 y 0.10 segundos**.
# - La onda **Q** es negativa, la **R** es positiva y la **S** vuelve a ser negativa.
# - Si todo el complejo es negativo, se llama **QS**.
#
# </details>
#
# <details>
# <summary>🟠 Onda T</summary>
#
# - Representa cuando los ventrículos se **recuperan** (repolarización).
# - Normalmente es **positiva**, excepto en algunas derivaciones.
# - Su forma es asimétrica: sube lento y baja rápido.
#
# </details>
#
# <details>
# <summary>🟣 Onda U</summary>
#
# - Es una onda pequeñita que aparece **después de la T**.
# - No siempre se ve y los médicos todavía no están seguros de qué significa.
# - Puede estar relacionada con los **músculos papilares** del corazón.
# - Se nota más en ciertos problemas como la **falta de potasio**.
#
# </details>
#
# ### 🧠 Recuerda
# - El ECG es como un **idioma del corazón**: cada onda nos cuenta una parte de su historia.
# - Si las ondas cambian de forma, pueden indicar un problema.
# - Por eso, los médicos lo usan para diagnosticar enfermedades del corazón.

# %% [markdown]
# # Reposo

# %%
import numpy as np
import matplotlib.pyplot as plt

# Cargar archivo
signal = np.loadtxt("Data_ECG/Reposo.txt")
# Seleccionar la columna 5 (para poder eliminar valores pequeños o ceros)
reposo = np.loadtxt("Data_ECG/Reposo.txt", comments="#")[:,5]

fs = 1000  # frecuencia de muestreo
t = np.arange(len(signal)) / fs

# Mostrar 5 segundos (5000 muestras)
samples = 5000
# Graficar
plt.figure(figsize=(12,5))
plt.plot(t[:samples], reposo[:samples], color="blue")

plt.title("Señal ECG - Señal en Reposo", fontsize=14, fontweight="bold")
plt.xlabel("Tiempo [s]", fontsize=12)
plt.ylabel("Amplitud [µV]", fontsize=12)

# Acotar el eje Y 
plt.ylim(0, 1000)
plt.grid(True, linestyle="--", alpha=0.6)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Contener respiración N°1

# %%
import numpy as np
import matplotlib.pyplot as plt

# Cargar datos
reposo = np.loadtxt("Data_ECG/Reposo.txt", comments="#")[:,5]
contener = np.loadtxt("Data_ECG/contener aire1.txt", comments="#")[:,5]

fs = 1000
t = np.arange(len(reposo)) / fs

# Mostrar 10 segundos (10000 muestras)
samples = 10000

plt.figure(figsize=(12,6))

plt.subplot(2,1,1)
plt.plot(t[:samples], reposo[:samples], color="blue")
plt.title("Señal ECG - Señal en reposo", fontsize=14, fontweight="bold")
plt.xlabel("Tiempo [s]"); plt.ylabel("Amplitud [µV]")
plt.ylim(0,1000); plt.grid(True, linestyle="--", alpha=0.6)

plt.subplot(2,1,2)
plt.plot(t[:samples], contener[:samples], color="red")
plt.title("Señal ECG - Contener Respiración N°1", fontsize=14, fontweight="bold")
plt.xlabel("Tiempo [s]"); plt.ylabel("Amplitud [µV]")
plt.ylim(0,1000); plt.grid(True, linestyle="--", alpha=0.6)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Contener respiración N°2

# %%
import numpy as np
import matplotlib.pyplot as plt

# Cargar datos
reposo = np.loadtxt("Data_ECG/Reposo.txt", comments="#")[:,5]
contener = np.loadtxt("Data_ECG/contener aire2.txt", comments="#")[:,5]

fs = 1000
t = np.arange(len(reposo)) / fs

# Mostrar 10 segundos (10000 muestras)
samples = 10000

plt.figure(figsize=(12,6))

plt.subplot(2,1,1)
plt.plot(t[:samples], reposo[:samples], color="blue")
plt.title("Señal ECG - Señal en reposo", fontsize=14, fontweight="bold")
plt.xlabel("Tiempo [s]"); plt.ylabel("Amplitud [µV]")
plt.ylim(0,1000); plt.grid(True, linestyle="--", alpha=0.6)

plt.subplot(2,1,2)
plt.plot(t[:samples], contener[:samples], color="red")
plt.title("Señal ECG - Contener Respiración N°2", fontsize=14, fontweight="bold")
plt.xlabel("Tiempo [s]"); plt.ylabel("Amplitud [µV]")
plt.ylim(0,1000); plt.grid(True, linestyle="--", alpha=0.6)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Contener respiración N°3

# %%
import numpy as np
import matplotlib.pyplot as plt

# Cargar datos
reposo = np.loadtxt("Data_ECG/Reposo.txt", comments="#")[:,5]
contener = np.loadtxt("Data_ECG/contener aire3.txt", comments="#")[:,5]

fs = 1000
t = np.arange(len(reposo)) / fs

# Mostrar 10 segundos (10000 muestras)
samples = 10000

plt.figure(figsize=(12,6))

plt.subplot(2,1,1)
plt.plot(t[:samples], reposo[:samples], color="blue")
plt.title("Señal ECG - Señal en reposo", fontsize=14, fontweight="bold")
plt.xlabel("Tiempo [s]"); plt.ylabel("Amplitud [µV]")
plt.ylim(0,1000); plt.grid(True, linestyle="--", alpha=0.6)

plt.subplot(2,1,2)
plt.plot(t[:samples], contener[:samples], color="red")
plt.title("Señal ECG - Contener Respiración N°3", fontsize=14, fontweight="bold")
plt.xlabel("Tiempo [s]"); plt.ylabel("Amplitud [µV]")
plt.ylim(0,1000); plt.grid(True, linestyle="--", alpha=0.6)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Posterior a Actividad física

# %%
import numpy as np
import matplotlib.pyplot as plt

# Cargar datos
reposo = np.loadtxt("Data_ECG/Reposo.txt", comments="#")[:,5]
contener = np.loadtxt("Data_ECG/correr.txt", comments="#")[:,5]

fs = 1000
t = np.arange(len(reposo)) / fs

# Mostrar 10 segundos (10000 muestras)
samples = 10000

plt.figure(figsize=(12,6))

plt.subplot(2,1,1)
plt.plot(t[:samples], reposo[:samples], color="blue")
plt.title("Señal ECG - Señal en reposo", fontsize=14, fontweight="bold")
plt.xlabel("Tiempo [s]"); plt.ylabel("Amplitud [µV]")
plt.ylim(0,1000); plt.grid(True, linestyle="--", alpha=0.6)

plt.subplot(2,1,2)
plt.plot(t[:samples], contener[:samples], color="red")
plt.title("Señal ECG - Correr", fontsize=14, fontweight="bold")
plt.xlabel("Tiempo [s]"); plt.ylabel("Amplitud [µV]")
plt.ylim(0,1000); plt.grid(True, linestyle="--", alpha=0.6)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Bibliografía 📖
# [1] Siontis, K. C., Noseworthy, P. A., Attia, Z. I., & Friedman, P. A. (2021). Artificial intelligence-enhanced electrocardiography in cardiovascular disease management. Nature Reviews Cardiology, 18(7), 465–478. https://doi.org/10.1038/s41569-020-00503-2
#
# [2] Ondas del Electrocardiograma. (s.f.). My EKG, La web del Electrocardiograma. https://www.my-ekg.com/generalidades-ekg/ondas-electrocardiograma.php
